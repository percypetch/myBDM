3_0.jpg
# /kaggle/input/bdm-2021-face/612110165_4_0.jpg
# /kaggle/input/bdm-2021-face/622110240_3_0.jpg
# /kaggle/input/bdm-2021-face/612110186_4_1.jpg
# /kaggle/input/bdm-2021-face/622110210_3_0.jpg
# /kaggle/input/bdm-2021-face/612110159_4_0.jpg
# /kaggle/input/bdm-2021-face/622110225_4_0.jpg
# /kaggle/input/bdm-2021-face/612110165_2_0.jpg
# /kaggle/input/bdm-2021-face/622110240_2_0.jpg
# /kaggle/input/bdm-2021-face/612110159_1_0.jpg
# /kaggle/input/bdm-2021-face/622110172_2_0.jpg
# /kaggle/input/bdm-2021-face/622110206_2_0.jpg
# /kaggle/input/bdm-2021-face/612110174_2_0.jpg
# /kaggle/input/bdm-2021-face/622110209_2_1.jpg

# %%
#!rm -rf train #Delete Data
#!rm -rf test #Delete Data

# %%
import glob
filename = glob.glob("/kaggle/input/bdm-2021-face/*.*")
filename[0].split("_")#splitชื่อไฟล์เพื่อดูประเภท
# Out:
# ['/kaggle/input/bdm-2021-face/622110140', '4', '0.jpg']

# %%
filename[0].split("_")[-1].split(".")[0] #0คือผช
# Out:
# '0'

# %%
label = np.array([float(item.split("_")[-1].split(".")[0]) for item in filename])

# %%
sum(label==0)
# Out:
# 64

# %%
# !mkdir train #สร้าง directory by Linux lang
# !mkdir train/male
# !mkdir train/female

# %%
#Train data
import shutil
for i in range(len(label)):
    if label[i] == 0:
        shutil.copy(filename[i], '/kaggle/working/train/male')
    else:
        shutil.copy(filename[i], '/kaggle/working/train/female')

# %%
# !mkdir test
# !mkdir test/male
# !mkdir test/female

# %%
import glob
filemale = glob.glob("./train/male/*.*")
filefemale = glob.glob("./train/female/*.*")

# %%
rng = np.random.RandomState(999)
midx = rng.choice(filemale,4, replace=False)
fidx = rng.choice(filefemale,2, replace=False)

# %%
for item in fidx:
    shutil.move(item,'./test/female/')
for item in midx:
    shutil.move(item,'./test/male/')

# %% [markdown]
# # Model

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        #rescale = 1.0/255.0,   # Intensity Normalized
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False,   # randomly flip images
        validation_split=0.2)

# %%
train_dir = './train'
batch_size = 5 #รูปผญมี15รูป
img_height = 100
img_width  = 100
train_generator = data_generator.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = data_generator.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation') # set as validation data
# Out:
# Found 63 images belonging to 2 classes.
# Found 15 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'female': 0, 'male': 1}

# %% [markdown]
# # CreateModel

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
# preparing the layers in the Convolutional Deep Neural Network
def create_model():
    tf.random.set_seed(999)
    tf.compat.v1.reset_default_graph() # Clear Model
    model = Sequential()
    model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', input_shape = train_generator.image_shape))
    model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation = 'relu'))
    #model.add(Conv2D(filters = 8, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Flatten())
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 32, activation = 'relu'))
    model.add(Dense(units = 16, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 8, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'sigmoid'))
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = create_model()

# %%
fitted_model = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 5s 408ms/step - loss: 29.0900 - accuracy: 0.5124 - val_loss: 1.2068 - val_accuracy: 0.2667
# Epoch 2/100
# 12/12 [==============================] - 4s 385ms/step - loss: 0.7855 - accuracy: 0.5438 - val_loss: 0.7109 - val_accuracy: 0.6000
# Epoch 3/100
# 12/12 [==============================] - 4s 353ms/step - loss: 0.5769 - accuracy: 0.8651 - val_loss: 0.6682 - val_accuracy: 0.7333
# Epoch 4/100
# 12/12 [==============================] - 4s 354ms/step - loss: 0.6006 - accuracy: 0.7716 - val_loss: 0.6515 - val_accuracy: 0.6000
# Epoch 5/100
# 12/12 [==============================] - 4s 349ms/step - loss: 0.6906 - accuracy: 0.6689 - val_loss: 0.5994 - val_accuracy: 0.7333
# Epoch 85/100
# 12/12 [==============================] - 4s 363ms/step - loss: 0.1388 - accuracy: 0.9055 - val_loss: 0.7492 - val_accuracy: 0.8667
# Epoch 86/100
# 12/12 [==============================] - 4s 365ms/step - loss: 0.2871 - accuracy: 0.8494 - val_loss: 0.1337 - val_accuracy: 1.0000
# Epoch 87/100
# 12/12 [==============================] - 4s 394ms/step - loss: 0.2185 - accuracy: 0.9271 - val_loss: 0.0555 - val_accuracy: 1.0000
# Epoch 88/100
# 12/12 [==============================] - 4s 315ms/step - loss: 0.2610 - accuracy: 0.8775 - val_loss: 1.0878 - val_accuracy: 0.8667
# Epoch 89/100
# 12/12 [==============================] - 4s 357ms/step - loss: 0.1077 - accuracy: 0.9791 - val_loss: 1.8156 - val_accuracy: 0.7333
# Epoch 90/100
# 12/12 [==============================] - 5s 326ms/step - loss: 0.2259 - accuracy: 0.9163 - val_loss: 1.6630 - val_accuracy: 0.8667
# Epoch 91/100
# 12/12 [==============================] - 4s 368ms/step - loss: 0.2473 - accuracy: 0.9524 - val_loss: 2.6596 - val_accuracy: 0.6667
# Epoch 92/100
# 12/12 [==============================] - 4s 373ms/step - loss: 0.0737 - accuracy: 0.9813 - val_loss: 1.1666 - val_accuracy: 0.7333
# Epoch 93/100
# 12/12 [==============================] - 4s 360ms/step - loss: 0.2436 - accuracy: 0.8679 - val_loss: 0.7116 - val_accuracy: 0.8000
# Epoch 94/100
# 12/12 [==============================] - 4s 324ms/step - loss: 0.1581 - accuracy: 0.9758 - val_loss: 0.9425 - val_accuracy: 0.7333
# Epoch 95/100
# 12/12 [==============================] - 4s 366ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 1.7166 - val_accuracy: 0.7333
# Epoch 96/100
# 12/12 [==============================] - 4s 313ms/step - loss: 0.7572 - accuracy: 0.9395 - val_loss: 1.0690 - val_accuracy: 0.7333
# Epoch 97/100
# 12/12 [==============================] - 4s 345ms/step - loss: 0.1936 - accuracy: 0.9264 - val_loss: 0.2751 - val_accuracy: 0.8667
# Epoch 98/100
# 12/12 [==============================] - 4s 333ms/step - loss: 0.3844 - accuracy: 0.8485 - val_loss: 0.5682 - val_accuracy: 0.7333
# Epoch 99/100
# 12/12 [==============================] - 5s 418ms/step - loss: 0.2535 - accuracy: 0.8776 - val_loss: 0.6340 - val_accuracy: 0.8667
# Epoch 100/100
# 12/12 [==============================] - 4s 385ms/step - loss: 0.1751 - accuracy: 0.9609 - val_loss: 1.0307 - val_accuracy: 0.8000

# %%
import matplotlib.pyplot as plt
# plotting accuracy and validation accuracy
accuracy = fitted_model.history['accuracy']
val_accuracy = fitted_model.history['val_accuracy']
plt.plot(range(len(accuracy)), accuracy, 'b-', label = 'accuracy')
plt.plot(range(len(val_accuracy)), val_accuracy, 'r-', label = 'val_accuracy')
plt.legend()

# %%
import glob
filefemale = glob.glob("./test/female/*.*")
filemale = glob.glob("./test/male/*.*")

# %%
from tensorflow.keras.preprocessing import image
# testing the model
plabel = []
for filename in filefemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==0)/len(plabel)
# Out:
# 0.0

# %%
plabel = []
for filename in filemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==1)/len(plabel)
# Out:
# 1.0
